# %% [markdown]
# # 2. 소트인사이드 (복습)

# %%
data = input()
array = []
for d in data:
    array.append(int(d))
    
array = sorted(array, reverse=True)

result = [str(d) for d in array]
print(''.join(result))
# Out:
#  2143
# 4321

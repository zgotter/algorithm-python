# %% [markdown]
# # 2. 수 찾기 (복습)

# %%
n = int(input())

A = {a for a in input().split()}

m = int(input())

B = [b for b in input().split()]

for b in B:
    if b in A:
        print(1)
    else:
        print(0)
# Out:
#  5
#  4 1 5 2 3
#  5
#  1 3 7 9 5
# 1
# 1
# 0
# 0
# 1
